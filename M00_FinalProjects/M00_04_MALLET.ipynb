# %% [markdown]
# # Metadata
#
# ```
# Course:   DS 5001
# Module:   00 Final Projects
# Topic:    Using MALLET
# ```

# %% [markdown]
# # Notes
#
# See Appendix below information on how download and install <a href="https://mimno.github.io/Mallet/topics">MALLET</a>.

# %% [markdown]
# # Set Up

# %%
data_home = "../data"
local_lib = "../lib"
data_prefix = 'novels'
OHCO = ['book_id','chap_id','para_num','sent_num','token_num']

# %%
max_words = 10000

# For MALLET
num_topics = 20
num_iters = 1000
show_interval = 100

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import CORPUS

# %%
LIB = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-LIB.csv").set_index(OHCO[:1])

# %%
CORPUS = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-CORPUS.csv").set_index(OHCO)

# %%
CORPUS.head()
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy

# %% [markdown]
# # Create DOC

# %%
def gather_docs(CORPUS, ohco_level, term_col='term_str'):
    OHCO = CORPUS.index.names
    CORPUS[term_col] = CORPUS[term_col].astype('str')
    DOC = CORPUS.groupby(OHCO[:ohco_level])[term_col].apply(lambda x:' '.join(x)).to_frame('doc_str')
    return DOC

# %%
DOC = gather_docs(CORPUS, 2)

# %%
DOC['n_tokens'] = DOC.doc_str.apply(lambda x: len(x.split()))

# %%
DOC
# Out:
#                                                               doc_str  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     n_tokens
# book_id    chap_id
# adventures 1            8608
#            2            9197
#            3            7020
#            4            9685
#            5            7365
# ...                      ...
# udolpho    54           5605
#            55           4164
#            56           2522
#            57            977
# usher      1            7212
#
# [320 rows x 2 columns]

# %% [markdown]
# ## Dump corpus to CSV file

# %%
mallet_corpus = DOC.join(LIB)[['doc_str','author_id']]
mallet_corpus.columns = 'doc_content doc_label'.split()
mallet_corpus[['doc_label','doc_content']].to_csv('novels-corpus.csv', index=False)

# %% [markdown]
# ## MALLET Time

# %% [markdown]
# ### Show MALLET options

# %%
mallet_home = "/Users/rca2t1/opt/mallet/bin"

# %%
! which mallet
# Out:
# mallet not found

# %% [markdown]
# ### Import corpus

# %%
# !{mallet_home}/mallet import-file --input novels-corpus.csv --output novels-corpus.mallet --keep-sequence TRUE

# %% [markdown]
# ### Train topics

# %%
# !{mallet_home}/mallet train-topics --input novels-corpus.mallet --num-topics {num_topics} --num-iterations {num_iters} \
--output-doc-topics novels-doc-topics.txt \
--output-topic-keys novels-topic-keys.txt \
--word-topic-counts-file novels-word-topic-counts-file.txt \
--topic-word-weights-file novels-topic-word-weights-file.txt \
--xml-topic-report novels-topic-report.xml \
--xml-topic-phrase-report novels-topic-phrase-report.xml \
--show-topics-interval {show_interval} \
--use-symmetric-alpha false  \
--optimize-interval 100 \
--diagnostics-file novels-diagnostics.xml
# Out:
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 15717
# total tokens: 1164070
# <10> LL/token: -9.08484
# <20> LL/token: -8.58206
# <30> LL/token: -8.39933
# <40> LL/token: -8.29954
# <50> LL/token: -8.23222
# <60> LL/token: -8.18517
# <70> LL/token: -8.14851
# <80> LL/token: -8.12487
# <90> LL/token: -8.10386
#
# 0	0.25	the emily said and not but montoni was that from for she annette had madame this what castle who heard
# 1	0.25	and was had that which but the with when his could for from heart not yet then before into all
# 2	0.25	the that have and been was not but this were upon one which from would for its some will what
# 3	0.25	the with which not this their are than our more his must has may and its who for into full
# 4	0.25	and the that for not all her his she with when there but then our some shall van was him
# 5	0.25	the his was upon from with not and your him but for every were matilda agnes antonia what have ambrosio
# 6	0.25	the that was you tuppence tommy she his sir poirot said but dont her then there julius with and well
# 7	0.25	and the was his they were them door out said with him but hand their down one into its through
# 8	0.25	his you and your him for that with this himself own have shall will time life can would without the
# 9	0.25	the and they with their which them were now while till over count long along for some little light woods
# 10	0.25	her she the had was that for with his and which been him herself this upon valancourt would now much
# 11	0.25	the was had which her and that room she there from time into house back again door sergeant this with
# 12	0.25	and the this all with any for from other old young was new two paper daughter money without part morning
# 13	0.25	the was had his for there could and were with him but man been from came long would over might
# 14	0.25	you have that not what said will are and him but know all your has for see how can would
# 15	0.25	the and that his which upon have holmes with this then there you sir our one some said from man
# 16	0.25	the and his said him lord that sir will they but for you your edmund them with father was baron
# 17	0.25	the and that with was his had miss franklin for him rachel way have diamond lady them betteredge what said
# 18	0.25	and her she was not had but for very could been mrs miss that catherine would were them there the
# 19	0.25	the and that from was were its which this after all when among had one there even some where passed
#
# <100> LL/token: -8.0781
# <110> LL/token: -8.06257
# <120> LL/token: -8.04425
# <130> LL/token: -8.02827
# <140> LL/token: -8.01773
# <150> LL/token: -8.00516
# <160> LL/token: -7.99241
# <170> LL/token: -7.98764
# <180> LL/token: -7.97519
# <190> LL/token: -7.97051
#
# 0	0.25	the emily said and not but montoni was that for annette castle had madame she heard who this what count
# 1	0.25	and was but had which with that not for when could heart the yet should father first might towards eyes
# 2	0.25	the that and have was been not upon but this for were all its now one what will such would
# 3	0.25	the which with this their not who are than our been from one must its may into these those some
# 4	0.25	and the that not her for all she when his with then him our some there van helsing shall was
# 5	0.25	the and was upon your from not that matilda his were but agnes antonia every with for ambrosio lorenzo theodore
# 6	0.25	the that she and you was tuppence tommy her but sir mrs poirot said out julius about dont yes not
# 7	0.25	and the his they was with were them said him door out down their its all upon old into about
# 8	0.25	his him and you that have with your himself for would from not will own time had this shall life
# 9	0.25	the they and with their his aubert them now for while woods along over were mountains into which little count
# 10	0.25	her she the had and was that with which for been this herself upon now would valancourt till all when
# 11	0.25	the was had and her that room she from there which out into with time have been house door left
# 12	0.25	the and with any work this for young all other money project name gutenberg years information from five england can
# 13	0.25	the was had his but for there could and were with would that man him came been way all might
# 14	0.25	you that have not what said for will are and but your this all know has can how him see
# 15	0.25	and the that which upon his holmes have our sir this then some one with very there from well you
# 16	0.25	the and lord said his sir will they that him edmund your but was them for you baron with all
# 17	0.25	the and that sergeant franklin miss rachel diamond way with for betteredge which about sir had was blake cuff out
# 18	0.25	and her she not was the for very had but catherine they miss could were mrs with been would them
# 19	0.25	the and that from which was had were some when after its this among these but more still one light
#
# <200> LL/token: -7.96137
# <210> LL/token: -7.95658
# <220> LL/token: -7.95837
# <230> LL/token: -7.95419
# <240> LL/token: -7.95047
# <250> LL/token: -7.94375
# <260> LL/token: -7.93896
# <270> LL/token: -7.93195
# <280> LL/token: -7.92948
# <290> LL/token: -7.92627
#
# 0	0.25	the emily and but said not montoni was for that annette castle who heard this what she chamber had count
# 1	0.25	and was but the had with for not when which heart that yet father should could eyes towards love before
# 2	0.25	the that and have not been upon this but was were from one for its all evidence any what about
# 3	0.25	the which with this their who are our some been than into from not may one here its those has
# 4	0.25	and the that not her all for she when his there but with our some him van then have helsing
# 5	0.25	the and was your you upon not from his matilda with but that every agnes antonia were for ambrosio lorenzo
# 6	0.25	the tuppence she her tommy and but that mrs you was poirot sir about not julius dont said well yes
# 7	0.25	and the his they with them said down him their was were out upon one door its old great all
# 8	0.25	his him that and have with not will for from himself would had your own these well this time other
# 9	0.25	the and with his their they aubert them woods while where over mountains for into along count who blanche seemed
# 10	0.25	her she the had and was with which that been upon for herself now could valancourt this when from than
# 11	0.25	the was had and that she her room out with into there time been have from door first took left
# 12	0.25	the and with work this any project gutenberg for works all use other england terms public are was office can
# 13	0.25	the was had and for his there could but with that would were man way him came other been all
# 14	0.25	you that and have what said not for your are will this all but know can him how must see
# 15	0.25	and the that which upon his holmes have sir our very some there then with well one this about you
# 16	0.25	the and lord said his sir your but you they edmund was will him for that baron with them philip
# 17	0.25	the and which miss sergeant franklin rachel for that diamond way with betteredge had about when sir again blake what
# 18	0.25	and her was not she the for but catherine very they could miss had were such with their mrs tilney
# 19	0.25	the and that which from was were had they this some now its when after more among these one through
#
# [beta: 0.01799]
# 16	0.1191	the and lord his sir said they edmund your will was baron you him upon them philip with all but
# 17	0.11131	the and which miss sergeant franklin rachel diamond her way betteredge them when sir for again had lady blake cuff
# 18	0.17481	and not her was catherine she they very for but miss could them mrs tilney such their being general been
# 19	0.41744	the and that which was from had they were this some now but when light these its through into more
#
# [beta: 0.02239]
# <500> LL/token: -7.85397
# <510> LL/token: -7.85212
# <520> LL/token: -7.84565
# <530> LL/token: -7.84159
# <540> LL/token: -7.84125
# <550> LL/token: -7.84268
# <560> LL/token: -7.83891
# <570> LL/token: -7.84091
# <580> LL/token: -7.83851
# <590> LL/token: -7.8364
#
# 0	0.09358	emily the but not montoni said she valancourt annette madame who was count them that then castle had this their
# 1	0.35908	and was but not had when that which yet your father life with myself should could heart our might felt
# 2	0.1461	the not that have upon been but this was which there its very all has and about body thus for
# 3	0.44904	the with which their were this who one been are other all its from our than may some first into
# 4	0.09433	and that not the all her for when she our him van helsing may shall have then must are lucy
# 5	0.07194	his upon not your but you was with them agnes antonia him ambrosio lorenzo every from the matilda still then
# 6	0.07948	she her tuppence tommy poirot mrs but sir julius was you not inglethorp yes dont said they then about did
# 7	0.22564	and scrooge they his said their its upon them old like with young ghost christmas spirit cried dont him little
# 8	0.51104	his and that for him have had from not would will this himself own only with such without same these
# 9	0.16253	the and with aubert they their his woods which them mountains over blanche among where along whose little evening chateau
# 10	0.38791	her the she and was had with which when for been that herself from now could than all after upon
# 11	0.48445	the was and had that room out been door house from into with hand have little time there two after
# 12	0.06219	the manfred said thou not isabella gutenberg project matilda thy lord theodore this your hippolita but princess thee prince work
# 13	0.43975	the his and was with there for him could but had were down them all out over came way one
# 14	0.62777	you and that have not said what but for your will this with are all know him can see must
# 15	0.09958	that upon holmes which have and our sir has very the man been his should from watson some said this
# 16	0.08544	the and lord sir said his you they edmund your him was baron will them philip but upon with shall
# 17	0.08637	the miss sergeant franklin rachel her which diamond when way betteredge and them she own blake lady cuff again sir
# 18	0.13648	not her was and catherine she they very but could miss them tilney mrs for their such being isabella morland
# 19	0.46965	the and that was had which from they this were for now some upon but with its light through when
#
# [beta: 0.02309]
# <600> LL/token: -7.83608
# <610> LL/token: -7.83211
# <620> LL/token: -7.82973
# <630> LL/token: -7.83008
# <640> LL/token: -7.82934
# <650> LL/token: -7.82789
# <660> LL/token: -7.82932
# <670> LL/token: -7.83092
# <680> LL/token: -7.83244
# <690> LL/token: -7.8326
#
# 0	0.08045	the emily but not montoni she said valancourt was annette who then madame count them that castle had they till
# 1	0.33478	and but was not had that when which myself yet your with father life before could should might heart eyes
# 2	0.11778	the that not have upon was been this but and which its there would body about very has any are
# 3	0.49444	the with their were which this who one from are been all other than first our man these some its
# 4	0.07744	and not that all for when the her she his him van our helsing shall then may are must went
# 5	0.05507	not your upon his but you was him agnes antonia with them ambrosio lorenzo matilda every then till the hand
# 6	0.06304	she her tuppence tommy poirot mrs but sir you not julius dont was inglethorp they yes said that about did
# 7	0.15544	and his scrooge they said its upon their old christmas ghost dont spirit young little them cried were about like
# 8	0.55904	his and that him for had have would this not from himself own will which without such time return only
# 9	0.14486	the and with aubert their they his them woods where among blanche over mountains evening its while along now scene
# 10	0.43435	her the she and was had with which when that been from for herself could more than now all heart
# 11	0.52886	the was had that and room out been into house time have from door hand two with little there any
# 12	0.03717	the said manfred not thou isabella gutenberg project thy matilda but lord this theodore hippolita your princess prince thee work
# 13	0.4613	the and his was there with him but had for could were down out them all one came over they
# 14	0.728	you and that have not for said what but your will with are this all know him one can must
# 15	0.08083	that upon holmes which have and his sir very our has this been man watson then sherlock not should you
# 16	0.06518	the and lord his sir said was edmund they your baron you them will with him philip upon but shall
# 17	0.07061	the miss sergeant franklin rachel which her she diamond way betteredge said and what when lady again sir blake with
# 18	0.10291	not and her catherine was they very but she could miss tilney them mrs for such general their were isabella
# 19	0.50263	the and that was which from had they for were this with upon now some into light its but through
#
# [beta: 0.0234]
# <700> LL/token: -7.83021
# <710> LL/token: -7.83151
# <720> LL/token: -7.82997
# <730> LL/token: -7.82943
# <740> LL/token: -7.82756
# <750> LL/token: -7.82857
# <760> LL/token: -7.82805
# <770> LL/token: -7.82748
# <780> LL/token: -7.82696
# <790> LL/token: -7.82733
#
# 0	0.07057	the emily montoni she but said not valancourt was annette madame who count had then castle them that when this
# 1	0.29817	and was but not had when that life myself your yet with which father might death felt feelings during before
# 2	0.09399	the that have not upon this was been but and there would its for has which will any body about
# 3	0.52914	the with their which were this one from who them are all been other our more first should some found
# 4	0.06451	and that the not all for when she van our helsing shall his may then her have some are him
# 5	0.04857	his your you upon was not with the but him agnes antonia ambrosio lorenzo every matilda till shall bosom hand
# 6	0.05579	she tuppence her tommy poirot but mrs sir you julius not dont inglethorp yes they said was that about well
# 7	0.10717	and scrooge his they its upon their said ghost christmas old spirit were them dont him cried young about ferrier
# 8	0.59214	his and that for him not had have but this from would himself will own which with such time only
# 9	0.13392	the and with aubert they their his woods among blanche mountains little where over now whose after which them its
# 10	0.47633	her the she and was had with which from been for when herself could than that upon would some should
# 11	0.55797	the was had that and been out room into have house door there time might hand when from any last
# 12	0.02512	the manfred said thou not isabella gutenberg project matilda thy lord theodore this your hippolita princess thee prince but castle
# 13	0.47597	the and his was there with him but for down were would out one could way had them face over
# 14	0.81461	you and that have for said not what but with your all will this are him know can see one
# 15	0.07326	that which upon holmes have his our very sir and has man from watson this sherlock been some then should
# 16	0.05464	the and his lord sir said edmund they was will him your baron philip them upon with shall you their
# 17	0.06459	the and miss sergeant which franklin her rachel with diamond she betteredge way lady blake own cuff said what godfrey
# 18	0.08333	not and catherine her was very they she miss tilney but mrs could such their for general being isabella them
# 19	0.5229	the and that was which had from they for but with this were upon some light now through into its
#
# [beta: 0.02369]
# <800> LL/token: -7.82515
# <810> LL/token: -7.82498
# <820> LL/token: -7.82563
# <830> LL/token: -7.82802
# <840> LL/token: -7.82884
# <850> LL/token: -7.83013
# <860> LL/token: -7.82864
# <870> LL/token: -7.83108
# <880> LL/token: -7.83101
# <890> LL/token: -7.82836
#
# 0	0.06478	the emily montoni but had said that she was valancourt who annette madame count not them they castle this then
# 1	0.25602	and was but had when not myself which yet father could eyes your might life heart death that even feelings
# 2	0.07861	the not that have upon been this but which there was for body will has its any would thus very
# 3	0.56042	the with and their which from were this one who are them been all first they found more may our
# <a href="https://mimno.github.io/Mallet/topics">Download MALLET here</a> | <a href="https://github.com/ontoligent/mazo">Mazo, a wrapper around MALLET to organize its output.</a>
#
# [![Build Status](https://travis-ci.com/MNCC/Mallet.svg?branch=master)](https://travis-ci.com/MNCC/Mallet)
# [![codecov](https://codecov.io/gh/MNCC/Mallet/branch/master/graph/badge.svg)](https://codecov.io/gh/MNCC/Mallet)
#
# Mallet
# ======
#
# Website: https://mimno.github.io/Mallet/
#
# MALLET is a Java-based package for statistical natural language processing, document classification, clustering, topic modeling, information extraction, and other machine learning applications to text.
#
# MALLET includes sophisticated tools for document classification: efficient routines for converting text to "features", a wide variety of algorithms (including Naïve Bayes, Maximum Entropy, and Decision Trees), and code for evaluating classifier performance using several commonly used metrics.
#
# In addition to classification, MALLET includes tools for sequence tagging for applications such as named-entity extraction from text. Algorithms include Hidden Markov Models, Maximum Entropy Markov Models, and Conditional Random Fields. These methods are implemented in an extensible system for finite state transducers.
#
# Topic models are useful for analyzing large collections of unlabeled text. The MALLET topic modeling toolkit contains efficient, sampling-based implementations of Latent Dirichlet Allocation, Pachinko Allocation, and Hierarchical LDA.
#
# Many of the algorithms in MALLET depend on numerical optimization. MALLET includes an efficient implementation of Limited Memory BFGS, among many other optimization methods.
#
# In addition to sophisticated Machine Learning applications, MALLET includes routines for transforming text documents into numerical representations that can then be processed efficiently. This process is implemented through a flexible system of "pipes", which handle distinct tasks such as tokenizing strings, removing stopwords, and converting sequences into count vectors.
#
# An add-on package to MALLET, called GRMM, contains support for inference in general graphical models, and training of CRFs with arbitrary graphical structure.
#
# ## Installation
#
# To build a Mallet 2.0 development release, you must have the Apache ant build tool installed. From the command prompt, first change to the mallet directory, and then type
# `ant`
#
# If `ant` finishes with `"BUILD SUCCESSFUL"`, Mallet is now ready to use.
#
# If you would like to deploy Mallet as part of a larger application, it is helpful to create a single ".jar" file that contains all of the compiled code. Once you have compiled the individual Mallet class files, use the command:
# `ant jar`
#
# This process will create a file "mallet.jar" in the "dist" directory within Mallet.
#
# ## Usage
#
# Once you have installed Mallet you can use it using the following command:
# ```
# bin/mallet [command] --option value --option value ...
# ```
# Type `bin/mallet` to get a list of commands, and use the option `--help` with any command to get a description of valid options.
#
# For details about the commands please visit the API documentation and website at: https://mimno.github.io/Mallet/
#
#
# ## List of Algorithms
#
# * Topic Modelling
#   * LDA
#   * Parallel LDA
#   * DMR LDA
#   * Hierarchical LDA
#   * Labeled LDA
#   * Polylingual Topic Model
#   * Hierarchical Pachinko Allocation Model (PAM)
#   * Weighted Topic Model
#   * LDA with integrated phrase discovery
#   * Word Embeddings (word2vec) using skip-gram with negative sampling
# * Classification
#   * AdaBoost
#   * Bagging
#   * Winnow
#   * C45 Decision Tree
#   * Ensemble Trainer
#   * Maximum Entropy Classifier (Multinomial Logistic Regression)
#   * Naive Bayes
#   * Rank Maximum Entropy Classifier
#   * Posterior Regularization Auxiliary Model
# * Clustering
#   * Greedy Agglomerative
#   * Hill Climbing
#   * K-Means
#   * K-Best
# * Sequence Prediction Models
#   * Conditional Random Fields
#   * Maximum Entropy Markov Models
#   * Hidden Markov Models
#   * Semi-Supervised Sequence Prediction Models
# * Linear Regression
